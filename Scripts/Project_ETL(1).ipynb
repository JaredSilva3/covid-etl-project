# %%
pip install psycopg2 pandas plotly streamlit
# Out:
# Requirement already satisfied: psycopg2 in f:\anaconda3\lib\site-packages (2.9.10)
# Requirement already satisfied: pandas in f:\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: plotly in f:\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: streamlit in f:\anaconda3\lib\site-packages (1.40.0)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in f:\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in f:\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in f:\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in f:\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: rich<14,>=10.14.0 in f:\anaconda3\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tornado<7,>=6.0.3 in f:\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: cachetools<6,>=4.0 in f:\anaconda3\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in f:\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: protobuf<6,>=3.20 in f:\anaconda3\lib\site-packages (from streamlit) (4.22.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in f:\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: click<9,>=7.0 in f:\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: toml<2,>=0.10.1 in f:\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: altair<6,>=4.0 in f:\anaconda3\lib\site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: watchdog<6,>=2.1.5 in f:\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: blinker<2,>=1.0.0 in f:\anaconda3\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: requests<3,>=2.27 in f:\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: pyarrow>=7.0 in f:\anaconda3\lib\site-packages (from streamlit) (18.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in f:\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: packaging<25,>=20 in f:\anaconda3\lib\site-packages (from streamlit) (22.0)
# Requirement already satisfied: narwhals>=1.5.2 in f:\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.13.2)
# Requirement already satisfied: jinja2 in f:\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in f:\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: colorama in f:\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in f:\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: six>=1.5 in f:\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in f:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in f:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2022.12.7)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in f:\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in f:\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in f:\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in f:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in f:\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: mdurl~=0.1 in f:\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in f:\anaconda3\lib\site-packages (2.9.10)

# %%
from sqlalchemy import create_engine
import pandas as pd

def connect_to_db():
    try:
        # Using SQLAlchemy to connect to PostgreSQL
        engine = create_engine("postgresql+psycopg2://postgres:dell@localhost:5432/demodb")
        print("Connection successful")
        return engine
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
conn = connect_to_db()
# Out:
# Connection successful

# %%
import pandas as pd

def extract_data():
    file_path = 'E:/covid-19-deaths-per-million-people.csv'  # Update with the actual path
    data = pd.read_csv(file_path)
    # Rename columns for simplicity
    data.columns = ['entity', 'iso_code', 'date', 'daily_deaths_per_million']
    return data

# %%
def transform_data(data):
    data = data.dropna().reset_index(drop=True)
    data = data.copy()
    data['date'] = pd.to_datetime(data['date'])
    return data

# %%
def create_table_and_load_data(engine, data, table_name):
    with engine.connect() as conn:
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            id SERIAL PRIMARY KEY,
            entity VARCHAR(255),
            iso_code VARCHAR(10),
            date DATE,
            daily_deaths_per_million FLOAT
        );
        """
        conn.execute(create_table_query)

        for _, row in data.iterrows():
            insert_query = f"""
                INSERT INTO {table_name} 
                (entity, iso_code, date, daily_deaths_per_million)
                VALUES (%s, %s, %s, %s)
            """
            conn.execute(insert_query, (row['entity'], row['iso_code'], row['date'], row['daily_deaths_per_million']))

# %%
def run_etl_pipeline():
    engine = connect_to_db()
    if engine:
        data = extract_data()
        transformed_data = transform_data(data)
        
        # Load data into PostgreSQL
        create_table_and_load_data(engine, transformed_data, "covid_data")
        print("ETL pipeline completed.")
    else:
        print("Failed to connect to the database.")

# %%
run_etl_pipeline()
# Out:
# Connection successful
# ETL pipeline completed.

# %%
def fetch_filtered_data(engine, table_name, filter_column, filter_value):
    with engine.connect() as conn:
        query = f"SELECT * FROM {table_name} WHERE {filter_column} = %s"
        df = pd.read_sql(query, conn, params=(filter_value,))
    return df

# %%
engine = connect_to_db()

if engine:
    # Fetch filtered data (for Afghanistan)
    df = fetch_filtered_data(engine, "covid_data", "entity", "Afghanistan")
    print(df.head())
else:
    print("Failed to connect to the database.")
# Out:
# Connection successful
#    id       entity iso_code        date  daily_deaths_per_million
# 0   1  Afghanistan      AFG  2020-01-10                       0.0
# 1   2  Afghanistan      AFG  2020-01-11                       0.0
# 2   3  Afghanistan      AFG  2020-01-12                       0.0
# 3   4  Afghanistan      AFG  2020-01-13                       0.0
# 4   5  Afghanistan      AFG  2020-01-14                       0.0

# %%
import plotly.express as px

def visualize_data(df, x_col, y_col):
    fig = px.line(df, x=x_col, y=y_col, title="COVID-19 Deaths per Million Over Time")
    fig.show()

# %%
engine = connect_to_db()

if engine:
    # Fetch filtered data
    df = fetch_filtered_data(engine, "covid_data", "entity", "Afghanistan")
    if not df.empty:
        # Visualize the data if available
        visualize_data(df, x_col="date", y_col="daily_deaths_per_million")
    else:
        print("No data found for the given filter.")
else:
    print("Failed to connect to the database.")
# Out:
# Connection successful
# <div>                            <div id="4834e52a-8ff7-4499-a919-39d358f1315d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4834e52a-8ff7-4499-a919-39d358f1315d")) {                    Plotly.newPlot(                        "4834e52a-8ff7-4499-a919-39d358f1315d",                        [{"hovertemplate":"date=%{x}<br>daily_deaths_per_million=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2020-01-10","2020-01-11","2020-01-12","2020-01-13","2020-01-14","2020-01-15","2020-01-16","2020-01-17","2020-01-18","2020-01-19","2020-01-20","2020-01-21","2020-01-22","2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16